# %%
import cv2
import matplotlib.pylab as plt
import numpy as np

# %%
#renk oluşturma ve maskeleme

# %%
matris_random = np.random.randint(1,101,50)
print(matris_random)
print(type(matris_random))
# Out:
# [ 1 23 99 35 32 65  2 57 71 73 51 34 19 14  1 71 59 20 48 58 52 20 71 71
#  90 12  3 43  8 43 77  3 91 22 63 15 13 41 38 37 77 11 11 87 80 21 14 96
#  48  4]
# <class 'numpy.ndarray'>

# %%
width,height,channel = 300,300,3

img_red = np.zeros((width,height,channel),dtype=np.uint8)

img_red[:,:,0]=255

plt.imshow(img_red)
plt.axis("off")
# Out:
# (-0.5, 299.5, 299.5, -0.5)

# %%
#yesil 255 mavi 160
width,height,channel = 300,300,3

img_blue= np.zeros((width,height,channel),dtype=np.uint8)

img_blue[:,:,2]=160

plt.imshow(img_blue)
plt.axis("off")
# Out:
# (-0.5, 299.5, 299.5, -0.5)

# %%
#yesil 255 mavi 160
width,height,channel = 300,300,3

img_green= np.zeros((width,height,channel),dtype=np.uint8)

img_green[:,:,1]=255

plt.imshow(img_green)
plt.axis("off")
# Out:
# (-0.5, 299.5, 299.5, -0.5)

# %%
fig = plt.figure(figsize=(10,7))
rows = 1
columns = 3

fig.add_subplot(rows,columns,1)
plt.imshow(img_red)
plt.axis("off")
plt.title("RED")

fig.add_subplot(rows,columns,2)
plt.imshow(img_blue)
plt.axis("off")
plt.title("BLUE")

fig.add_subplot(rows,columns,3)
plt.imshow(img_green)
plt.axis("off")
plt.title("GREEN")
# Out:
# Text(0.5, 1.0, 'GREEN')

# %%
img_black = np.zeros((width,height,3),dtype=np.uint8)
img_white = np.ones((width,height,3),dtype=np.uint8)*255
img_gray_1= np.zeros((width,height,3),dtype=np.uint8)

img_gray_1[:,:,:]=128

img_gray_2 = np.random.randint(128,129,(width,height,3),dtype=np.uint8)

# %%
fig = plt.figure(figsize=(10,7),facecolor='purple')
rows = 2
columns = 2

fig.add_subplot(rows,columns,1)
plt.imshow(img_black)
plt.axis("off")
plt.title("BLACK")

fig.add_subplot(rows,columns,2)
plt.imshow(img_white)
plt.axis("off")
plt.title("WHİTE")

fig.add_subplot(rows,columns,3)
plt.imshow(img_gray_1)
plt.axis("off")
plt.title("GRAY")

fig.add_subplot(rows,columns,4)
plt.imshow(img_gray_2)
plt.axis("off")
plt.title("GRAY2")
# Out:
# Text(0.5, 1.0, 'GRAY2')

# %%
img_yellow = np.zeros((width,height,3),dtype=np.uint8)
img_yellow[:,:,0]=255
img_yellow[:,:,1]=255

# %%
fig = plt.figure(figsize=(10,7),facecolor='purple')
rows = 2
columns = 2

fig.add_subplot(rows,columns,1)
plt.imshow(img_yellow)
plt.axis("off")
plt.title("BLACK")
# Out:
# Text(0.5, 1.0, 'BLACK')

# %%
width,height,channel = 300,420,3
img_flag_germany=np.zeros((width,height,channel),dtype=np.uint8)

img_flag_germany[:100,:] = [0,0,0]

img_flag_germany[100:200,:] = [255,0,0]

img_flag_germany[200:300,:] = [255,255,0]

# %%
plt.imshow(img_flag_germany)
plt.axis("off")
plt.title("GERMANY")
# Out:
# Text(0.5, 1.0, 'GERMANY')

# %%
width,height,channel = 300,420,3
img_flag_russia=np.zeros((width,height,channel),dtype=np.uint8)

img_flag_russia[:100,:]=[255,255,255]

img_flag_russia[100:200,:]=[0,0,255]

img_flag_russia[200:300, :] = [255, 0, 0]

plt.imshow(img_flag_russia)
plt.axis("off")
plt.title("RUSSİA")
# Out:
# Text(0.5, 1.0, 'RUSSİA')

# %%
width,height,channel = 300,420,3
img_flag_belçika=np.zeros((width,height,channel),dtype=np.uint8)

img_flag_belçika[:140,:] = [0,0,0]

img_flag_belçika[:,140:280] = [255,255,0]

img_flag_belçika[:,280:420] = [255,0,0]

plt.imshow(img_flag_belçika)
plt.axis("off")
plt.title("Belçika")
# Out:
# Text(0.5, 1.0, 'Belçika')

# %%
width,height,channel = 300,420,3
img_flag_russia=np.zeros((width,height,channel),dtype=np.uint8)

img_flag_russia[:100,:]=[255,255,255]

img_flag_russia[100:200,:]=[0,0,255]

img_flag_russia[200:300, :] = [255, 0, 0]

plt.imshow(img_flag_russia)
plt.axis("off")
plt.title("RUSSİA")
# Out:
# Text(0.5, 1.0, 'RUSSİA')

# %%
mask_red=(img_flag_russia[:,:,0]==255)&(img_flag_russia[:,:,1]==0)&(img_flag_russia[:,:,2]==0)

img_flag_russia[mask_red]=[255,255,0]

plt.imshow(img_flag_russia)
plt.axis("off")
# Out:
# (-0.5, 419.5, 299.5, -0.5)

# %%
width,height,channel = 300,420,3
img_flag_belçika=np.zeros((width,height,channel),dtype=np.uint8)

img_flag_belçika[:140,:] = [0,0,0]

img_flag_belçika[:,140:280] = [255,255,0]

img_flag_belçika[:,280:420] = [255,0,0]

plt.imshow(img_flag_belçika)
plt.axis("off")
plt.title("Belçika")
# Out:
# Text(0.5, 1.0, 'Belçika')

# %%
mask_red=(img_flag_belçika[:,:,0]==0)&(img_flag_belçika[:,:,1]==0)&(img_flag_belçika[:,:,2]==0)

img_flag_belçika[mask_red]=[0,0,255]

plt.imshow(img_flag_belçika)
plt.axis("off")
# Out:
# (-0.5, 419.5, 299.5, -0.5)
